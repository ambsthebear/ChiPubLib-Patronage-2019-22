# %% [markdown]
# ## Joining and cleaning data using SQL and Pandas

# %%
#IMPORTS
import pandas as pd
import mysql.connector as connection

# %% [markdown]
# #### Set up db variable

# %%
chipublib_db = connection.connect(host="localhost", database="chipublib_database1923", user="root", password="ROOTpass", use_pure=True)

# %% [markdown]
# ### Join queries by category

# %%
circulation_query = """SELECT 2019_circulation.BRANCH,
    2019_circulation.ADDRESS,
    2019_circulation.CITY,
    2019_circulation.ZIP,
    2019_circulation.JANUARY,
    2019_circulation.FEBRUARY,
    2019_circulation.MARCH,
    2019_circulation.APRIL,
    2019_circulation.MAY,
    2019_circulation.JUNE,
    2019_circulation.JULY,
    2019_circulation.AUGUST,
    2019_circulation.SEPTEMBER,
    2019_circulation.OCTOBER,
    2019_circulation.NOVEMBER,
    2019_circulation.DECEMBER,
    2019_circulation.YTD,
    2019_circulation.YEAR,
    2020_circulation.BRANCH,
    2020_circulation.ADDRESS,
    2020_circulation.CITY,
    2020_circulation.ZIP,
    2020_circulation.JANUARY,
    2020_circulation.FEBRUARY,
    2020_circulation.MARCH,
    2020_circulation.APRIL,
    2020_circulation.MAY,
    2020_circulation.JUNE,
    2020_circulation.JULY,
    2020_circulation.AUGUST,
    2020_circulation.SEPTEMBER,
    2020_circulation.OCTOBER,
    2020_circulation.NOVEMBER,
    2020_circulation.DECEMBER,
    2020_circulation.YTD,
    2020_circulation.YEAR,
    2021_circulation.BRANCH,
    2021_circulation.ADDRESS,
    2021_circulation.CITY,
    2021_circulation.ZIP,
    2021_circulation.JANUARY,
    2021_circulation.FEBRUARY,
    2021_circulation.MARCH,
    2021_circulation.APRIL,
    2021_circulation.MAY,
    2021_circulation.JUNE,
    2021_circulation.JULY,
    2021_circulation.AUGUST,
    2021_circulation.SEPTEMBER,
    2021_circulation.OCTOBER,
    2021_circulation.NOVEMBER,
    2021_circulation.DECEMBER,
    2021_circulation.YTD,
    2021_circulation.YEAR,
    2022_circulation.BRANCH,
    2022_circulation.ADDRESS,
    2022_circulation.CITY,
    2022_circulation.ZIP,
    2022_circulation.JANUARY,
    2022_circulation.FEBRUARY,
    2022_circulation.MARCH,
    2022_circulation.APRIL,
    2022_circulation.MAY,
    2022_circulation.JUNE,
    2022_circulation.JULY,
    2022_circulation.AUGUST,
    2022_circulation.SEPTEMBER,
    2022_circulation.OCTOBER,
    2022_circulation.NOVEMBER,
    2022_circulation.DECEMBER,
    2022_circulation.YTD,
    2022_circulation.YEAR,
    2023_circulation.BRANCH,
    2023_circulation.ADDRESS,
    2023_circulation.CITY,
    2023_circulation.ZIP,
    2023_circulation.JANUARY,
    2023_circulation.FEBRUARY,
    2023_circulation.MARCH,
    2023_circulation.APRIL,
    2023_circulation.MAY,
    2023_circulation.YTD,
    2023_circulation.YEAR
    FROM 2019_circulation
    JOIN 2020_circulation
    ON 2019_circulation.BRANCH = 2020_circulation.BRANCH
    JOIN 2021_circulation
    ON 2019_circulation.BRANCH = 2021_circulation.BRANCH
    JOIN 2022_circulation
    ON 2019_circulation.BRANCH = 2022_circulation.BRANCH
    JOIN 2023_circulation
    ON 2019_circulation.BRANCH = 2023_circulation.BRANCH
    """

joined_circulation_df = pd.read_sql(circulation_query, chipublib_db)

computer_sessions_query = """SELECT 2019_computer_sessions.BRANCH,
    2019_computer_sessions.ADDRESS,
    2019_computer_sessions.CITY,
    2019_computer_sessions.ZIP,
    2019_computer_sessions.JANUARY,
    2019_computer_sessions.FEBRUARY,
    2019_computer_sessions.MARCH,
    2019_computer_sessions.APRIL,
    2019_computer_sessions.MAY,
    2019_computer_sessions.JUNE,
    2019_computer_sessions.JULY,
    2019_computer_sessions.AUGUST,
    2019_computer_sessions.SEPTEMBER,
    2019_computer_sessions.OCTOBER,
    2019_computer_sessions.NOVEMBER,
    2019_computer_sessions.DECEMBER,
    2019_computer_sessions.YTD,
    2019_computer_sessions.YEAR,
    2020_computer_sessions.BRANCH,
    2020_computer_sessions.ADDRESS,
    2020_computer_sessions.CITY,
    2020_computer_sessions.ZIP,
    2020_computer_sessions.JANUARY,
    2020_computer_sessions.FEBRUARY,
    2020_computer_sessions.MARCH,
    2020_computer_sessions.APRIL,
    2020_computer_sessions.MAY,
    2020_computer_sessions.JUNE,
    2020_computer_sessions.JULY,
    2020_computer_sessions.AUGUST,
    2020_computer_sessions.SEPTEMBER,
    2020_computer_sessions.OCTOBER,
    2020_computer_sessions.NOVEMBER,
    2020_computer_sessions.DECEMBER,
    2020_computer_sessions.YTD,
    2020_computer_sessions.YEAR,
    2021_computer_sessions.BRANCH,
    2021_computer_sessions.ADDRESS,
    2021_computer_sessions.CITY,
    2021_computer_sessions.ZIP,
    2021_computer_sessions.JANUARY,
    2021_computer_sessions.FEBRUARY,
    2021_computer_sessions.MARCH,
    2021_computer_sessions.APRIL,
    2021_computer_sessions.MAY,
    2021_computer_sessions.JUNE,
    2021_computer_sessions.JULY,
    2021_computer_sessions.AUGUST,
    2021_computer_sessions.SEPTEMBER,
    2021_computer_sessions.OCTOBER,
    2021_computer_sessions.NOVEMBER,
    2021_computer_sessions.DECEMBER,
    2021_computer_sessions.YTD,
    2021_computer_sessions.YEAR,
    2022_computer_sessions.BRANCH,
    2022_computer_sessions.ADDRESS,
    2022_computer_sessions.CITY,
    2022_computer_sessions.ZIP,
    2022_computer_sessions.JANUARY,
    2022_computer_sessions.FEBRUARY,
    2022_computer_sessions.MARCH,
    2022_computer_sessions.APRIL,
    2022_computer_sessions.MAY,
    2022_computer_sessions.JUNE,
    2022_computer_sessions.JULY,
    2022_computer_sessions.AUGUST,
    2022_computer_sessions.SEPTEMBER,
    2022_computer_sessions.OCTOBER,
    2022_computer_sessions.NOVEMBER,
    2022_computer_sessions.DECEMBER,
    2022_computer_sessions.YTD,
    2022_computer_sessions.YEAR,
    2023_computer_sessions.BRANCH,
    2023_computer_sessions.ADDRESS,
    2023_computer_sessions.CITY,
    2023_computer_sessions.ZIP,
    2023_computer_sessions.JANUARY,
    2023_computer_sessions.FEBRUARY,
    2023_computer_sessions.MARCH,
    2023_computer_sessions.APRIL,
    2023_computer_sessions.MAY,
    2023_computer_sessions.YTD,
    2023_computer_sessions.YEAR
    FROM 2019_computer_sessions
    JOIN 2020_computer_sessions
    ON 2019_computer_sessions.BRANCH = 2020_computer_sessions.BRANCH
    JOIN 2021_computer_sessions
    ON 2019_computer_sessions.BRANCH = 2021_computer_sessions.BRANCH
    JOIN 2022_computer_sessions
    ON 2019_computer_sessions.BRANCH = 2022_computer_sessions.BRANCH
    JOIN 2023_computer_sessions
    ON 2019_computer_sessions.BRANCH = 2023_computer_sessions.BRANCH
    """

joined_computer_sessions_df = pd.read_sql(computer_sessions_query, chipublib_db)

visitors_query = """SELECT 2019_visitors.BRANCH,
    2019_visitors.ADDRESS,
    2019_visitors.CITY,
    2019_visitors.ZIP,
    2019_visitors.JANUARY,
    2019_visitors.FEBRUARY,
    2019_visitors.MARCH,
    2019_visitors.APRIL,
    2019_visitors.MAY,
    2019_visitors.JUNE,
    2019_visitors.JULY,
    2019_visitors.AUGUST,
    2019_visitors.SEPTEMBER,
    2019_visitors.OCTOBER,
    2019_visitors.NOVEMBER,
    2019_visitors.DECEMBER,
    2019_visitors.YTD,
    2019_visitors.YEAR,
    2020_visitors.BRANCH,
    2020_visitors.ADDRESS,
    2020_visitors.CITY,
    2020_visitors.ZIP,
    2020_visitors.JANUARY,
    2020_visitors.FEBRUARY,
    2020_visitors.MARCH,
    2020_visitors.APRIL,
    2020_visitors.MAY,
    2020_visitors.JUNE,
    2020_visitors.JULY,
    2020_visitors.AUGUST,
    2020_visitors.SEPTEMBER,
    2020_visitors.OCTOBER,
    2020_visitors.NOVEMBER,
    2020_visitors.DECEMBER,
    2020_visitors.YTD,
    2020_visitors.YEAR,
    2021_visitors.BRANCH,
    2021_visitors.ADDRESS,
    2021_visitors.CITY,
    2021_visitors.ZIP,
    2021_visitors.JANUARY,
    2021_visitors.FEBRUARY,
    2021_visitors.MARCH,
    2021_visitors.APRIL,
    2021_visitors.MAY,
    2021_visitors.JUNE,
    2021_visitors.JULY,
    2021_visitors.AUGUST,
    2021_visitors.SEPTEMBER,
    2021_visitors.OCTOBER,
    2021_visitors.NOVEMBER,
    2021_visitors.DECEMBER,
    2021_visitors.YTD,
    2021_visitors.YEAR,
    2022_visitors.BRANCH,
    2022_visitors.ADDRESS,
    2022_visitors.CITY,
    2022_visitors.ZIP,
    2022_visitors.JANUARY,
    2022_visitors.FEBRUARY,
    2022_visitors.MARCH,
    2022_visitors.APRIL,
    2022_visitors.MAY,
    2022_visitors.JUNE,
    2022_visitors.JULY,
    2022_visitors.AUGUST,
    2022_visitors.SEPTEMBER,
    2022_visitors.OCTOBER,
    2022_visitors.NOVEMBER,
    2022_visitors.DECEMBER,
    2022_visitors.YTD,
    2022_visitors.YEAR,
    2023_visitors.BRANCH,
    2023_visitors.ADDRESS,
    2023_visitors.CITY,
    2023_visitors.ZIP,
    2023_visitors.JANUARY,
    2023_visitors.FEBRUARY,
    2023_visitors.MARCH,
    2023_visitors.APRIL,
    2023_visitors.MAY,
    2023_visitors.YTD,
    2023_visitors.YEAR
    FROM 2019_visitors
    JOIN 2020_visitors
    ON 2019_visitors.BRANCH = 2020_visitors.BRANCH
    JOIN 2021_visitors
    ON 2019_visitors.BRANCH = 2021_visitors.BRANCH
    JOIN 2022_visitors
    ON 2019_visitors.BRANCH = 2022_visitors.BRANCH
    JOIN 2023_visitors
    ON 2019_visitors.BRANCH = 2023_visitors.BRANCH
    """

joined_visitors_df = pd.read_sql(visitors_query, chipublib_db)
# Out:
# C:\Users\16306\AppData\Local\Temp\ipykernel_12512\454938726.py:95: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   joined_circulation_df = pd.read_sql(circulation_query, chipublib_db)
# C:\Users\16306\AppData\Local\Temp\ipykernel_12512\454938726.py:191: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   joined_computer_sessions_df = pd.read_sql(computer_sessions_query, chipublib_db)
# C:\Users\16306\AppData\Local\Temp\ipykernel_12512\454938726.py:287: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
# ...

# %% [markdown]
# ### Convert df to csv for analysis in Tableau

# %%
joined_circulation_df.to_csv("circulation_stats.csv", encoding='utf-8', index=False)
joined_computer_sessions_df.to_csv("computer_sessions_stats.csv", encoding='utf-8', index=False)
joined_visitors_df.to_csv("visitors_stats.csv", encoding='utf-8', index=False)
